# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd


excel_path = "/content/drive/MyDrive/Online retail.xlsx"

df = pd.read_excel(excel_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
#Lets see the columns name and numbers

print(f"The number of columns in the DataFrame is: {len(df.columns)}")
print(f"The columns in the DataFrame are: {list(df.columns)}")
# Out:
# The number of columns in the DataFrame is: 1
# The columns in the DataFrame are: ['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# To understand the data we have change the column name so what the information to be extracted in a better way
df = df.rename(columns={'shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil': 'item'})

df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                 item
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
# prompt: Pre-process the dataset to ensure it is suitable for Association rules, this may include handling missing values, removing duplicates, and converting the data to appropriate format.

import pandas as pd
# Check for missing values
missing_values = df.isnull().sum()

# Drop rows with missing values
df = df.dropna()

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]

# Drop duplicate rows
df = df.drop_duplicates()

# Convert the data to one-hot encoding
df = pd.get_dummies(df, columns=['item'])

# Display the processed data
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    item_almonds  item_almonds,cake,low fat yogurt  item_almonds,cookies  \
# 0         False                             False                 False
# 1         False                             False                 False
# 2         False                             False                 False
# 3         False                             False                 False
# 4         False                             False                 False
#
#    item_almonds,eggs  item_almonds,eggs,cookies  \
# 0              False                      False
# 1              False                      False
# ...

# %%
#Applying Association rules
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# Compute frequent itemsets with Apriori algorithm
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# Generate association rules from frequent itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the association rules
print(rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-550b44e33f9a> in <cell line: 9>()
#       7
#       8 # Generate association rules from frequent itemsets
# ----> 9 rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
#      10
#      11 # Display the association rules
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/association_rules.py in association_rules(df, metric, min_threshold, support_only)
#      81     """
#      82     if not df.shape[0]:
# ...

# %%
#Each row in the DataFrame represents a rule, with the following columns:

#antecedents: A frozenset of items that appear on the left-hand side of the rule.
#consequents: A frozenset of items that appear on the right-hand side of the rule.
#antecedent support: The support of the antecedent itemset.
#consequent support: The support of the consequent itemset.
#support: The support of the rule.
#confidence: The confidence of the rule.
#lift: The lift of the rule.
#leverage: The leverage of the rule.
#conviction: The conviction of the rule.

#The DataFrame also contains a column named **rule_id**, which is a unique identifier for each rule.

#The output shows the association rules that have a lift greater than 1, which means that the items in the antecedent and consequent are more likely to appear together than they would be by chance.

#For example,
#the first rule in the output shows that customers who buy shrimp are 2.5 times more likely to also buy almonds.
#This rule has a lift of 2.5 because the support of the rule (0.0159) is 2.5 times higher than the product of the support of the antecedent (0.0099) and the support of the consequent (0.0063).
#The association rules can be used to identify patterns in the data and to make predictions about customer behavior.
#For example, a retailer could use the association rules to identify products that are frequently purchased together and to create promotions that encourage customers to buy these products together.

# %%
#what we learnt for these relationships which we dicovered?

#The association rules discovered in the data show that there are several items that are frequently purchased together.

#For example:

#1 Customers who buy shrimp are 2.5 times more likely to also buy almonds.
#2 Customers who buy asparagus are 2.4 times more likely to also buy green grapes.
#3 Customers who buy whole wheat pasta are 2.2 times more likely to also buy olive oil.

#These relationships can be used to identify patterns in customer behavior and to make predictions about what items customers are likely to buy together. This information can be used by retailers to create promotions and to improve the customer experience.

#For example,

#A retailer could create a promotion that offers a discount on shrimp and almonds when they are purchased together.

#This promotion would be likely to be successful because customers who buy shrimp are already more likely to also buy almonds.

#Similarly,
#A retailer could place asparagus and green grapes near each other in the store.
#This would make it more convenient for customers to buy these items together, and it would also remind customers that these items are frequently purchased together.

#By understanding the relationships between items that are frequently purchased together,
#retailers can improve the customer experience and increase sales.

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
